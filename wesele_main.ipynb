# %%
# import podstawowych bibliotek

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps

# %%
# wczytanie danych do data frame'u

! git clone https://github.com/jackcooler/wesele
# Out:
# fatal: destination path 'wesele' already exists and is not an empty directory.

# %%
wesele = pd.read_csv("wesele/wesele.csv")
hotel = pd.read_csv("wesele/wesele_hotel.csv")

# %%
wesele
# Out:
#     lp  ilosc_osob  dorosli  potencjalne_dzieci      odpowiedz  ilosc_gosci  \
# 0    1           2        2                 NaN  Potwierdzenie          2.0
# 1    2           2        2                 NaN         Odmowa          0.0
# 2    3           1        1                 NaN         Odmowa          0.0
# 3    4           2        2                 NaN         Odmowa          0.0
# 4    5           2        2                 NaN  Potwierdzenie          2.0
# ..  ..         ...      ...                 ...            ...          ...
# 90  91           2        2                 NaN         Odmowa          0.0
# 91  92           2        2                 NaN  Potwierdzenie          2.0
# 92  93           2        2                 NaN  Potwierdzenie          2.0
# 93  94           2        2                 NaN         Odmowa          0.0
# 94  95           2        2                 NaN  Potwierdzenie          2.0
#
# ...

# %%
wesele.head()
# Out:
#    lp  ilosc_osob  dorosli  potencjalne_dzieci      odpowiedz  ilosc_gosci  \
# 0   1           2        2                 NaN  Potwierdzenie          2.0
# 1   2           2        2                 NaN         Odmowa          0.0
# 2   3           1        1                 NaN         Odmowa          0.0
# 3   4           2        2                 NaN         Odmowa          0.0
# 4   5           2        2                 NaN  Potwierdzenie          2.0
#
#   ilosc_osob_hotel ilosc_pokoi ilosc_dob sniadanie_1_dzien  koperta_pln  \
# 0                2           1         2                 2       5000.0
# 1                -           -         -               NaN       3000.0
# 2                -           -         -               NaN       1000.0
# 3                -           -         -               NaN          NaN
# 4                2           1         1                 1       1000.0
#
#    koperta_usd  koperta_eur  koperta_gbp zal_przybycia przybycie  kobiety  \
# ...

# %%
hotel
# Out:
#    liczba_osob  ilosc_pokoi  ilosc_dob  sniadania_dni    typ_pokoju  cena  \
# 0            2          5.0        2.0            2.0    dwuosobowy   NaN
# 1            1          2.0        2.0            2.0   jednosobowy   NaN
# 2            2         14.0        1.0            1.0    dwuosobowy   NaN
# 3            1          3.0        1.0            1.0  jednoosobowy   NaN
# 4            2          1.0        2.0            NaN    dwuosobowy   NaN
# 5            1          1.0        2.0            NaN   jednosobowy   NaN
# 6            2          1.0        1.0            NaN    dwuosobowy   NaN
# 7            3          NaN        NaN            1.0           NaN   NaN
#
#    wartosc           usluga          od          do
# 0      NaN  pokoj_sniadanie  2023-10-06  2023-10-08
# 1      NaN  pokoj_sniadanie  2023-10-06  2023-10-08
# 2      NaN  pokoj_sniadanie  2023-10-07  2023-10-08
# 3      NaN  pokoj_sniadanie  2023-10-07  2023-10-08
# ...

# %%
cena_sniadania = 40
cena_pokoj = 180

# %%
hotel["sniadania_dni"] = hotel["sniadania_dni"].fillna(0)
hotel["ilosc_pokoi"] = hotel["ilosc_pokoi"].fillna(0)
hotel["ilosc_dob"] = hotel["ilosc_dob"].fillna(0)
hotel["wartosc"] = hotel["wartosc"].fillna(0)
hotel["cena"] = hotel["ilosc_dob"] * cena_pokoj + hotel["sniadania_dni"] * hotel["liczba_osob"] * cena_sniadania
hotel
# Out:
#    liczba_osob  ilosc_pokoi  ilosc_dob  sniadania_dni    typ_pokoju   cena  \
# 0            2          5.0        2.0            2.0    dwuosobowy  520.0
# 1            1          2.0        2.0            2.0   jednosobowy  440.0
# 2            2         14.0        1.0            1.0    dwuosobowy  260.0
# 3            1          3.0        1.0            1.0  jednoosobowy  220.0
# 4            2          1.0        2.0            0.0    dwuosobowy  360.0
# 5            1          1.0        2.0            0.0   jednosobowy  360.0
# 6            2          1.0        1.0            0.0    dwuosobowy  180.0
# 7            3          0.0        0.0            1.0           NaN  120.0
#
#    wartosc           usluga          od          do
# 0      0.0  pokoj_sniadanie  2023-10-06  2023-10-08
# 1      0.0  pokoj_sniadanie  2023-10-06  2023-10-08
# 2      0.0  pokoj_sniadanie  2023-10-07  2023-10-08
# 3      0.0  pokoj_sniadanie  2023-10-07  2023-10-08
# ...

# %%
hotel["wartosc"] = hotel["ilosc_pokoi"] * hotel["cena"]
hotel.at[7,"wartosc"] = hotel.at[7,"cena"]
hotel
# Out:
#    liczba_osob  ilosc_pokoi  ilosc_dob  sniadania_dni    typ_pokoju   cena  \
# 0            2          5.0        2.0            2.0    dwuosobowy  520.0
# 1            1          2.0        2.0            2.0   jednosobowy  440.0
# 2            2         14.0        1.0            1.0    dwuosobowy  260.0
# 3            1          3.0        1.0            1.0  jednoosobowy  220.0
# 4            2          1.0        2.0            0.0    dwuosobowy  360.0
# 5            1          1.0        2.0            0.0   jednosobowy  360.0
# 6            2          1.0        1.0            0.0    dwuosobowy  180.0
# 7            3          0.0        0.0            1.0           NaN  120.0
#
#    wartosc           usluga          od          do
# 0   2600.0  pokoj_sniadanie  2023-10-06  2023-10-08
# 1    880.0  pokoj_sniadanie  2023-10-06  2023-10-08
# 2   3640.0  pokoj_sniadanie  2023-10-07  2023-10-08
# 3    660.0  pokoj_sniadanie  2023-10-07  2023-10-08
# ...

# %%
wesele.describe()
# Out:
#               lp  ilosc_osob    dorosli  potencjalne_dzieci  ilosc_gosci  \
# count  95.000000   95.000000  95.000000           20.000000    89.000000
# mean   48.000000    2.378947   1.989474            1.900000     1.157303
# std    27.568098    0.980436   0.555337            0.718185     0.987408
# min     1.000000    1.000000   1.000000            1.000000     0.000000
# 25%    24.500000    2.000000   2.000000            1.750000     0.000000
# 50%    48.000000    2.000000   2.000000            2.000000     2.000000
# 75%    71.500000    2.000000   2.000000            2.000000     2.000000
# max    95.000000    6.000000   6.000000            4.000000     3.000000
#
#        koperta_pln  koperta_usd  koperta_eur  koperta_gbp    kobiety  \
# count    56.000000          1.0          1.0          1.0  95.000000
# mean   1248.214286        500.0        600.0        200.0   0.557895
# std     992.149379          NaN          NaN          NaN   0.520143
# ...

# %%
wesele.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lp                  95 non-null     int64
#  1   ilosc_osob          95 non-null     int64
#  2   dorosli             95 non-null     int64
#  3   potencjalne_dzieci  20 non-null     float64
#  4   odpowiedz           89 non-null     object
#  5   ilosc_gosci         89 non-null     float64
#  6   ilosc_osob_hotel    92 non-null     object
#  7   ilosc_pokoi         92 non-null     object
#  8   ilosc_dob           92 non-null     object
#  9   sniadanie_1_dzien   80 non-null     object
#  10  koperta_pln         56 non-null     float64
#  11  koperta_usd         1 non-null      float64
#  12  koperta_eur         1 non-null      float64
#  13  koperta_gbp         1 non-null      float64
#  14  zal_przybycia       95 non-null     object
# ...

# %%
hotel.describe()
# Out:
#        liczba_osob  ilosc_pokoi  ilosc_dob  sniadania_dni       cena  \
# count     8.000000     8.000000   8.000000       8.000000    8.00000
# mean      1.750000     3.375000   1.375000       0.875000  307.50000
# std       0.707107     4.565007   0.744024       0.834523  136.04096
# min       1.000000     0.000000   0.000000       0.000000  120.00000
# 25%       1.000000     1.000000   1.000000       0.000000  210.00000
# 50%       2.000000     1.500000   1.500000       1.000000  310.00000
# 75%       2.000000     3.500000   2.000000       1.250000  380.00000
# max       3.000000    14.000000   2.000000       2.000000  520.00000
#
#           wartosc
# count     8.00000
# mean   1100.00000
# std    1300.85686
# min     120.00000
# 25%     315.00000
# 50%     510.00000
# 75%    1310.00000
# max    3640.00000

# %%
liczba_gosci = wesele["ilosc_gosci"].sum()
print(liczba_gosci)
# Out:
# 103.0

# %%
wszyscy = wesele["ilosc_osob"].sum()
print(wszyscy)
# Out:
# 226

# %%
wszyscy_dorosli = wesele["dorosli"].sum()
print(wszyscy_dorosli)
# Out:
# 189

# %%
# bez wstrzymanych zaproszeń
wesele_zapr = wesele.drop([15, 16, 25, 76, 77, 78], axis=0)

wesele_zapr["koprta_pln"] = wesele_zapr["koperta_pln"].fillna(0)
wesele_zapr["koperta_usd"] = wesele_zapr["koperta_usd"].fillna(0)
wesele_zapr["koperta_eur"] = wesele_zapr["koperta_eur"].fillna(0)
wesele_zapr["koperta_gbp"] = wesele_zapr["koperta_gbp"].fillna(0)

wesele_zapr
# Out:
#     lp  ilosc_osob  dorosli  potencjalne_dzieci      odpowiedz  ilosc_gosci  \
# 0    1           2        2                 NaN  Potwierdzenie          2.0
# 1    2           2        2                 NaN         Odmowa          0.0
# 2    3           1        1                 NaN         Odmowa          0.0
# 3    4           2        2                 NaN         Odmowa          0.0
# 4    5           2        2                 NaN  Potwierdzenie          2.0
# ..  ..         ...      ...                 ...            ...          ...
# 90  91           2        2                 NaN         Odmowa          0.0
# 91  92           2        2                 NaN  Potwierdzenie          2.0
# 92  93           2        2                 NaN  Potwierdzenie          2.0
# 93  94           2        2                 NaN         Odmowa          0.0
# 94  95           2        2                 NaN  Potwierdzenie          2.0
#
# ...

# %%
wesele_zapr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89 entries, 0 to 94
# Data columns (total 21 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   lp                  89 non-null     int64
#  1   ilosc_osob          89 non-null     int64
#  2   dorosli             89 non-null     int64
#  3   potencjalne_dzieci  19 non-null     float64
#  4   odpowiedz           83 non-null     object
#  5   ilosc_gosci         83 non-null     float64
#  6   ilosc_osob_hotel    86 non-null     object
#  7   ilosc_pokoi         86 non-null     object
#  8   ilosc_dob           86 non-null     object
#  9   sniadanie_1_dzien   76 non-null     object
#  10  koperta_pln         53 non-null     float64
#  11  koperta_usd         89 non-null     float64
#  12  koperta_eur         89 non-null     float64
#  13  koperta_gbp         89 non-null     float64
#  14  zal_przybycia       89 non-null     object
# ...

# %%
koszty_sala = {
    "menu": 396 * liczba_gosci,
    "stol_wiejski": 30 * 50,
    "menu_dj_fot": 198 * 2,
    "korkowe": 15 * (liczba_gosci - 3),
    "zaiks": 200
}

koszty_inne = {
    "ciasta": 3675,
    "tort": 1575,
    "fotograf": 4140,
    "DJ": 4500,
    "dekoracje": 5000,
    "zaproszenia": 200,
    "winietki": 103,
    "prezenty": 103,
    "suknia": 5340,
    "buty": 300,
    "bizuteria": 780,
    "kosmetyczka": 180,
    "fryzjer": 100,
    "garnitur_full": 2549,
    "fryzjer": 75,
    "obraczki": 3770,
    "ksiadz": 1000,
    "organista": 0,
    "kwiaty": 250,
    "wodka": round(27.99 * 120, 2),
    "piwo": 232,
    "cytrynowka": 150
}

# %%
koszty_sala
# Out:
# {'menu': 40788.0,
#  'stol_wiejski': 1500,
#  'menu_dj_fot': 396,
#  'korkowe': 1500.0,
#  'zaiks': 200}

# %%
usluga_sala = list(koszty_sala.keys())
koszt = list(koszty_sala.values())

plt.bar(range(len(koszty_sala)), koszt, tick_label = usluga_sala)
plt.show()

# %%
fig, ax = plt.subplots()

colors = ['#FFB70D', '#84FFB2', '#500404', '#573E03', '#382BB0']

ax.pie(koszty_sala.values(), labels=koszty_sala.keys(), autopct='%1.1f%%', pctdistance=1.25, labeldistance=1.45, colors=colors, wedgeprops = { 'linewidth' : 0.5, 'edgecolor' : 'black' })
plt.show()

# %%
koszt_hotel = hotel['wartosc'].sum()
koszt_hotel
# Out:
# 8800.0

# %%
koszt_sala = sum(koszty_sala.values())
koszt_sala
koszty_inne_suma = sum(koszty_inne.values())
koszty_inne_suma
# Out:
# 37280.8

# %%
koszt_wszystko = {
    'Koszty sali': koszt_sala,
    'Koszty hotelu': koszt_hotel,
    'Koszty pozostałe': koszty_inne_suma
}

fig, ax = plt.subplots()

colors = ['#382BB0', '#D199F2', '#DFFF83']

ax.pie(koszt_wszystko.values(), labels=koszt_wszystko.keys(), autopct='%1.1f%%', colors=colors, wedgeprops = { 'linewidth' : 0.75, 'edgecolor' : 'black' })
ax.set_title("Udział procentowy kosztów")

plt.show()

# %%
lista_uslug = list(koszt_wszystko.keys())
lista_kosztow = list(koszt_wszystko.values())

def addlabels(x,y):
  for i in range(len(x)):
        ax.text(i, y[i], y[i], ha = 'center',
                bbox = dict(facecolor = 'lightgreen', alpha =.8))

fig, ax = plt.subplots()
ax.bar(range(len(koszt_wszystko)), lista_kosztow, tick_label = lista_uslug, color=colors, edgecolor='black', linewidth= 0.75)
addlabels(lista_uslug, lista_kosztow)

ax.set_title("Podział kosztów wesela wraz z wartościami")

plt.show()

# %%
wszystko = sum(koszt_wszystko.values())
wszystko
# Out:
# 90464.8

# %%
# Out:
# {'ciasta': 3675,
#  'tort': 1575,
#  'fotograf': 4140,
#  'DJ': 4500,
#  'dekoracje': 5000,
#  'zaproszenia': 200,
#  'winietki': 103,
#  'prezenty': 103,
#  'suknia': 5340,
#  'buty': 300,
#  'bizuteria': 780,
#  'kosmetyczka': 180,
#  'fryzjer': 75,
#  'garnitur_full': 2549,
#  'obraczki': 3770,
#  'ksiadz': 1000,
#  'organista': 0,
#  'kwiaty': 250,
#  'wodka': 3358.8,
#  'piwo': 232,
#  'cytrynowka': 150,
#  'sala': 44384.0}

# %%
usluga_inne = list(koszty_inne.keys())
koszt1 = list(koszty_inne.values())

plt.bar(range(len(koszty_inne)), koszt1, tick_label = usluga_inne)
plt.xticks(rotation=75, ha='right')
plt.show()
